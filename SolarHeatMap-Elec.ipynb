# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import datetime
import seaborn as sns

# %%
#import the Solar Panel dataframe
df = pd.read_csv('Solar_Ninja_Data_1kW.csv')
df['time'] = pd.to_datetime(df['time'])

# %%
#insert relevant columns to compute a heatmap from
df['Date']=df['time'].dt.date
df['Month']=df['time'].dt.month_name()
df['Day']=df['time'].dt.day_name()
df['Hour']=df['time'].dt.hour


#sort the dataframe columns in a desired order
df = df[['Month','Hour','electricity']]

# %%
#formatting the dataframe so that it can be plotted into a heatmap

df1 = df.groupby(['Month', 'Hour'],sort=False).agg(['mean'])
df1.columns=df1.columns.droplevel(0)
df1.reset_index(inplace=True)
heatmap_data = pd.pivot_table(df1, values='mean', index=['Month'], columns='Hour')

# %%
cols=list(heatmap_data)
heatmap_data = heatmap_data.loc[:, cols]
Months=df1.Month.unique().tolist()
heatmap_data=heatmap_data.loc[Months]

# %%
sns.heatmap(heatmap_data)
plt.xlabel("Hour of the Day", size=14)
plt.ylabel("Month", size=14)
plt.title(" Solar Panel Electricity (kW) 2015", size=14)
# Out:
# Text(0.5, 1.0, ' Solar Panel Electricity (kW) 2015')

# %%
heatmap_data
# Out:
# Hour        0    1    2    3         4         5         6         7   \
# Month
# January    0.0  0.0  0.0  0.0  0.000774  0.004613  0.022129  0.058129
# February   0.0  0.0  0.0  0.0  0.000964  0.005464  0.023036  0.065964
# March      0.0  0.0  0.0  0.0  0.000774  0.005097  0.027742  0.099290
# April      0.0  0.0  0.0  0.0  0.000800  0.009833  0.062400  0.174567
# May        0.0  0.0  0.0  0.0  0.003065  0.030677  0.105065  0.214516
# June       0.0  0.0  0.0  0.0  0.008233  0.033000  0.106033  0.206000
# July       0.0  0.0  0.0  0.0  0.002871  0.028710  0.092742  0.193645
# August     0.0  0.0  0.0  0.0  0.000258  0.010032  0.066032  0.170968
# September  0.0  0.0  0.0  0.0  0.000700  0.004767  0.028233  0.112567
# October    0.0  0.0  0.0  0.0  0.000290  0.003613  0.015290  0.050097
# November   0.0  0.0  0.0  0.0  0.000400  0.004300  0.018467  0.050033
# December   0.0  0.0  0.0  0.0  0.000516  0.004871  0.021323  0.050226
#
# Hour             8         9   ...        14        15        16        17  \
# Month                          ...
# January    0.119484  0.205871  ...  0.178935  0.104290  0.049645  0.022806
# February   0.152857  0.267321  ...  0.343286  0.209964  0.087429  0.025357
# March      0.213484  0.328548  ...  0.376355  0.265774  0.138871  0.042387
# April      0.318167  0.420933  ...  0.384833  0.290333  0.179100  0.074867
# May        0.325484  0.425065  ...  0.394677  0.303581  0.205194  0.112097
# June       0.305433  0.397267  ...  0.371267  0.296167  0.206567  0.113867
# July       0.297387  0.395194  ...  0.396226  0.295161  0.191548  0.097161
# August     0.291419  0.398613  ...  0.403194  0.299290  0.190516  0.085452
# September  0.231833  0.354967  ...  0.360700  0.247200  0.130900  0.041233
# October    0.128000  0.222645  ...  0.233806  0.152484  0.064935  0.018871
# November   0.099100  0.161233  ...  0.210233  0.120733  0.051700  0.020767
# December   0.082516  0.132419  ...  0.154677  0.088419  0.049355  0.021323
#
# Hour             18        19   20   21   22   23
# Month
# January    0.006258  0.001065  0.0  0.0  0.0  0.0
# February   0.007250  0.001214  0.0  0.0  0.0  0.0
# March      0.005935  0.001194  0.0  0.0  0.0  0.0
# April      0.016967  0.001000  0.0  0.0  0.0  0.0
# May        0.036581  0.006419  0.0  0.0  0.0  0.0
# June       0.042800  0.012467  0.0  0.0  0.0  0.0
# July       0.032548  0.004935  0.0  0.0  0.0  0.0
# August     0.017226  0.001161  0.0  0.0  0.0  0.0
# September  0.005533  0.000600  0.0  0.0  0.0  0.0
# October    0.005032  0.000387  0.0  0.0  0.0  0.0
# November   0.005100  0.000500  0.0  0.0  0.0  0.0
# December   0.004968  0.000774  0.0  0.0  0.0  0.0
#
# [12 rows x 24 columns]

# %%
heatmap_data.sum().sum()
# Out:
# 36.932134178187404
